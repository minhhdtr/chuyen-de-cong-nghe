# %%
import json 

file_path = 'data.json'

# Đọc tệp JSON và chuyển đổi thành từ điển
with open(file_path, 'r') as file:
    json_data = json.load(file)



# In ra từ điển đã chuyển đổi
# Out:
# [{'time': 'Đọc kết quả XSMB ngày 25-03-2024', 'db': '16342', 'g1': '75754', 'g2': ['28913', '37346'], 'g3': ['86642', '45535', '81914', '94696', '52321', '96022'], 'g4': ['8692', '8838', '9702', '1399'], 'g5': ['7019', '7237', '7661', '94696', '52321', '96022'], 'g6': ['8692', '8838', '9702', '1399'], 'g7': ['8692', '8838', '9702', '1399']}, {'time': 'Đọc kết quả XSMB ngày 24-03-2024', 'db': '88274', 'g1': '06693', 'g2': ['53350', '57784'], 'g3': ['04071', '89897', '75341', '98348', '75312', '33461'], 'g4': ['9003', '5952', '0115', '9805'], 'g5': ['3069', '2189', '5874', '98348', '75312', '33461'], 'g6': ['9003', '5952', '0115', '9805'], 'g7': ['9003', '5952', '0115', '9805']}, {'time': 'Đọc kết quả XSMB ngày 23-03-2024', 'db': '59882', 'g1': '35161', 'g2': ['80009', '90230'], 'g3': ['27850', '78279', '76809', '32621', '30855', '65708'], 'g4': ['4114', '7900', '0301', '0473'], 'g5': ['6540', '7127', '8212', '32621', '30855', '65708'], 'g6': ['4114', '7900', '0301', '0473'], 'g7': ['4
# ...

# %%
import pandas as pd

pd.DataFrame(json_data)
# Out:
#                                 time     db     g1              g2  \
# 0   Đọc kết quả XSMB ngày 25-03-2024  16342  75754  [28913, 37346]
# 1   Đọc kết quả XSMB ngày 24-03-2024  88274  06693  [53350, 57784]
# 2   Đọc kết quả XSMB ngày 23-03-2024  59882  35161  [80009, 90230]
# 3   Đọc kết quả XSMB ngày 22-03-2024  95371  07286  [23998, 54295]
# 4   Đọc kết quả XSMB ngày 21-03-2024  81866  15018  [97738, 52425]
# ..                               ...    ...    ...             ...
# 78  Đọc kết quả XSMB ngày 03-01-2024  62495  61083  [88825, 25631]
# 79  Đọc kết quả XSMB ngày 02-01-2024  10956  44230  [11435, 21121]
# 80  Đọc kết quả XSMB ngày 01-01-2024  42932  66272  [27370, 68541]
# 81  Đọc kết quả XSMB ngày 31-12-2023  73758  80689  [75152, 42067]
# 82  Đọc kết quả XSMB ngày 30-12-2023  59380  24170  [49908, 46745]
#
#                                             g3                        g4  \
# 0   [86642, 45535, 81914, 94696, 52321, 96022]  [8692, 8838, 9702, 1399]
# ...
